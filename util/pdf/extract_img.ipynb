# %%
from pathlib import Path

# %%
# Create a Path object
pdf_path = Path('/Users/phuocpham/Downloads/Raymond_HSNL_230730.pdf')

output_dir=Path('/Users/phuocpham/Projects/raymond/terrestrial-tower/public/images/HSNL')

# Print the Path object
print(pdf_path)
print(output_dir)
# Out:
# /Users/phuocpham/Downloads/Raymond_HSNL_230730.pdf
# /Users/phuocpham/Projects/raymond/terrestrial-tower/public/images/HSNL

# %%
from extract_img_pdf import main

# %%
main(pdf_path,output_dir, range(36, 90))
# Out:
# Saved combined image for width 3386 on page 37 to /Users/phuocpham/Projects/raymond/terrestrial-tower/public/images/HSNL/page_37/1.jpg
# Saved combined image for width 3843 on page 37 to /Users/phuocpham/Projects/raymond/terrestrial-tower/public/images/HSNL/page_37/2.jpg
# Saved combined image for width 294 on page 37 to /Users/phuocpham/Projects/raymond/terrestrial-tower/public/images/HSNL/page_37/3.jpg
# Saved combined image for width 3315 on page 38 to /Users/phuocpham/Projects/raymond/terrestrial-tower/public/images/HSNL/page_38/1.jpg
# Saved combined image for width 3329 on page 38 to /Users/phuocpham/Projects/raymond/terrestrial-tower/public/images/HSNL/page_38/2.jpg
# Saved combined image for width 294 on page 38 to /Users/phuocpham/Projects/raymond/terrestrial-tower/public/images/HSNL/page_38/3.jpg
# Saved combined image for width 4582 on page 39 to /Users/phuocpham/Projects/raymond/terrestrial-tower/public/images/HSNL/page_39/1.jpg
# ...
